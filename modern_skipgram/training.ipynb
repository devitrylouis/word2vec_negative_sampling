# %%
from code.utils import text2sentences
from code.skipgram import SkipGram
from code.evaluation import most_similar

# %% [markdown]
# # Get data and define SkipGram

# %%
# Read data
train_sentences = text2sentences('news.en-00000-of-00100')

# %% [markdown]
# # Training

# %% [markdown]
# One of the most discriminant factor in gaining speed was drawing all negative samples at once.

# %%
# Instanciate SkipGram
sg = SkipGram(train_sentences[0:100000], embedding_dimension = 100, negative_rate = 5,\
         window_size = 5, min_count = 5, subsampling = None,\
         epochs = 15, stepsize = 0.05, dynamic_window = False)

# %%
sg.train(frame = 50000)
# Out:
# Epochs: 7
# - Progression : 100000 contexts done out of 2104325
# - Mean loss so far : 0.30661387800133794
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-b9951c586052> in <module>
# ----> 1 sg_sub_dyn.train(frame = 50000)
#
# ~/Downloads/SkipGram/code/skipgram.py in train(self, frame, batch_size)
#      95             for i, current in enumerate(current_words):
#      96                 ## Run batch
# ---> 97                 w0, w1, epoch_error, sgd_count = run_batch(self, current, contexts_corpus[i], negative_samples[i,:], w0, w1, epoch_error, sgd_count)
#      98                 display_progression(self, epoch, i, epoch_error, sgd_count, frame = frame, nb = len(current_words))
#      99
#
# ~/Downloads/SkipGram/code/batch.py in run_batch(sg, current, contexts_word, negative_samples, w0, w1, epoch_error, sgd_count)
#      45
#      46     # Keep track of the error (mean probabilities error)
# ---> 47     epoch_error += np.sum(np.abs(output - target))
#      48     sgd_count += target.shape[0]
#      49
#
# KeyboardInterrupt:

# %%
sg.save('custom_w2v')

# %%
# Instanciate SkipGram
sg_sub_syn = SkipGram(train_sentences[0:500000], embedding_dimension = 100, negative_rate = 5,\
         window_size = 5, min_count = 5, subsampling = 1e-5,\
         epochs = 15, stepsize = 0.05, dynamic_window = True)

# %%
sg_sub_syn.train(frame = 50000)
# Out:
# Epochs: 3
# - Progression : 250000 contexts done out of 1911384
# - Mean loss so far : 0.16783750449505222
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-e542de1669a2> in <module>
# ----> 1 sg_sub_syn.train(frame = 50000)
#
# ~/Downloads/SkipGram/code/skipgram.py in train(self, frame, batch_size)
#      95             for i, current in enumerate(current_words):
#      96                 ## Run batch
# ---> 97                 w0, w1, epoch_error, sgd_count = run_batch(self, current, contexts_corpus[i], negative_samples[i,:], w0, w1, epoch_error, sgd_count)
#      98                 display_progression(self, epoch, i, epoch_error, sgd_count, frame = frame, nb = len(current_words))
#      99
#
# ~/Downloads/SkipGram/code/batch.py in run_batch(sg, current, contexts_word, negative_samples, w0, w1, epoch_error, sgd_count)
#      38     # BACKWARD PASS
#      39     ## Gradient computations
# ---> 40     gradient_loss = gradients_custom(target, output, current_word, context_words)
#      41
#      42     ## Update
#
# ~/Downloads/SkipGram/code/batch.py in gradients_custom(target, prediction, current_word, context_words)
#      86
#      87     # Exact gradients
# ---> 88     grad_w0 = np.sum(error*context_words, axis = 1)
#      89     grad_w1 = np.outer(current_word, error)
#      90
#
# KeyboardInterrupt:

# %%
sg_sub_syn.save('custom_w2v_sub_dyn')

# %% [markdown]
# # Experiments

# %%
word2vec = SkipGram.load('custom_w2v.pickle')

# %%
most_similar(word2vec, 'usa')
# Out:
# {'usa': 1.0,
#  'suisse': 0.7672726036609514,
#  'beatty': 0.7655164243024473,
#  'headquartered': 0.7636662886219363,
#  'dean': 0.7585003986107081,
#  'proceeding': 0.7575639158110978,
#  'fidelity': 0.7560712397712148,
#  'cavendish': 0.7533033034577155,
#  'capitals': 0.7511627722404741,
#  'disgraced': 0.7494567789344412,
#  'sylvia': 0.7491028816416176,
#  'fossil': 0.7487050933058518,
#  'diego': 0.7486503106774396,
#  'inc': 0.7475751672083981,
#  'goldman': 0.7472281753026591,
#  'tanzania': 0.7470532130519582,
#  'vick': 0.7463719768445428,
#  'penalties': 0.7461091918052811,
#  'obligations': 0.7458386046535667,
#  'wanderers': 0.7454033167666596,
#  'angeles': 0.7449523832115784,
#  'awaits': 0.743244528669863,
#  'vibe': 0.7429692013227613,
#  'sevens': 0.7420837247546006,
#  'lapse': 0.7415615658525689,
#  'nyse': 0.7414698299785134,
#  'satisfaction': 0.7412678365977989,
#  'brad': 0.7400735005256507,
#  'xavier': 0.7398718627408309,
#  'sprint': 0.7397110558771944,
#  'dominate': 0.7395025653932393,
#  'prnewswirefirstcall': 0.7392298084801675,
#  'volkswagen': 0.7391185250773079,
#  'seinfeld': 0.7390053948131957,
#  'tiger': 0.7386802989740411,
#  'ranked': 0.7383175428935493,
#  'stearns': 0.7376973047783112,
#  'recoup': 0.7374700568241274,
#  'tmz': 0.7366385708032577,
#  'realty': 0.7361839607964504,
#  'murky': 0.7354343725868513,
#  'bury': 0.7352964939246339,
#  'prominently': 0.733935647692869,
#  'riches': 0.7336375853069759,
#  'paralympic': 0.7330494319698158,
#  'sony': 0.7329681051742929,
#  'exhibitions': 0.7328639795610244,
#  'fields': 0.732704104673354,
#  'ensued': 0.7322181353346241,
#  'fusion': 0.7317712324970107,
#  'mmorpg': 0.731574369370434,
#  'tree': 0.7312441697381525,
#  'timber': 0.7310860092543117,
#  'departments': 0.7309599509794926,
#  'supervision': 0.7309523219760259,
#  'accessed': 0.730654591528808,
#  'california': 0.7304840627724648,
#  'salaried': 0.7302253943676045,
#  'writings': 0.729971527622294,
#  'newlook': 0.7293510153873177,
#  'convince': 0.7288820254281831,
#  'cowboy': 0.7287491778875212,
#  'granted': 0.7285175286194998,
#  'automation': 0.7283519354298573,
#  'intel': 0.7282989033124287,
#  'envisaged': 0.7282876411389406,
#  'formerly': 0.7279806842679987,
#  'durban': 0.7278930201514373,
#  'lender': 0.7273355537875642,
#  'adams': 0.7269334841761259,
#  'leafs': 0.7269170543861199,
#  'madoff': 0.726697042023005,
#  'celebrating': 0.7265922326924473,
#  'ordnance': 0.7265275051440164,
#  'championship': 0.7265138636856854,
#  'swat': 0.7259330270338784,
#  'surgeons': 0.7256589859877309,
#  'fourth': 0.7255986383095132,
#  'host': 0.7255029890826811,
#  'cotton': 0.7254442926788947,
#  'hockey': 0.7252415417760307,
#  'conducting': 0.7252379132435314,
#  'accepts': 0.7251829897589585,
#  'gingrich': 0.7251078358555971,
#  'losses': 0.7247168270742865,
#  'richmond': 0.7246581539945972,
#  'wachovia': 0.7244400740403004,
#  'managers': 0.7243858141980002,
#  'yunnan': 0.7242274204178708,
#  'subtlety': 0.7242054151049279,
#  'arise': 0.7241461721441425,
#  'turco': 0.7240395079563381,
#  'subsidiary': 0.7238332322752626,
#  'sooner': 0.7238143698636663,
#  'pairs': 0.7235931799873874,
#  'jamaican': 0.7233776635206149,
#  'classaction': 0.7233539582111191,
#  'malaria': 0.723241759263817,
#  'emitter': 0.7226110016962916,
#  'tech': 0.7225325105639344,
#  'ethics': 0.7224854452620054,
#  'ltd': 0.7223976142533285,
#  'recorder': 0.7221917357344071,
#  'beyonce': 0.7221895559744623,
#  'huntington': 0.7221712048430566,
#  'hadn': 0.7221679663689159,
#  'dusted': 0.7221485699079501,
#  'medallist': 0.7220290284455059,
#  'prnewswireusnewswire': 0.7220040438672853,
#  'highend': 0.7219828763247544,
#  'orchestrated': 0.721754039598613,
#  'distributors': 0.7216054258424035,
#  'fia': 0.7212637702401214,
#  'gs': 0.7211703099424718,
#  'gossip': 0.7209760038561334,
#  'palo': 0.7209633371144478,
#  'werder': 0.7208636276652002,
#  'wolfsburg': 0.720846645832774,
#  'discussions': 0.7208306208258564,
#  'macroeconomic': 0.7207044756944969,
#  'merge': 0.7206320838342529,
#  'edinburgh': 0.720563261655389,
#  'society': 0.7205243056636856,
#  'interference': 0.7204565652768292,
#  'bridgend': 0.7203169404510406,
#  'emerged': 0.7201396380588279,
#  'carlo': 0.720046281595201,
#  'los': 0.7199860911242949,
#  'wash': 0.719970092342141,
#  'dominion': 0.7197759711969907,
#  'troubled': 0.7194689112681188,
#  'reigning': 0.7194550899026162,
#  'vineyards': 0.7194347157132562,
#  'dynasty': 0.7194006669590647,
#  'jpmorgan': 0.7193517061670011,
#  'academia': 0.7192496403890147,
#  'prnewswire': 0.7192217935597831,
#  'glendale': 0.719148828224186,
#  'internationals': 0.7189607705082869,
#  'mcnair': 0.7188467318695929,
#  'columbia': 0.718558872661373,
#  'anecdotal': 0.718554087537379,
#  'assemblyman': 0.7185408498077069,
#  'convinced': 0.7185292310210416,
#  'dan': 0.718444050998499,
#  'barbie': 0.7182285907307961,
#  'incompetent': 0.7180800252503479,
#  'russo': 0.7180387725540487,
#  'spiegel': 0.7179586226054055,
#  'der': 0.7178969291046475,
#  'ceo': 0.7178842610501617,
#  'drought': 0.7177971463868426,
#  'patience': 0.7176305048191485,
#  'ind': 0.7176071239269306,
#  'baa': 0.7176042505177932,
#  'brooks': 0.7169642905470025,
#  'horse': 0.7168787124514919,
#  'westchester': 0.7167875134308495,
#  'conclude': 0.7167268892328972,
#  'giles': 0.7166124555943654,
#  'ashe': 0.7166006582664827,
#  'row': 0.7165617797887999,
#  'annan': 0.7165041510131999,
#  'prosecution': 0.716453183808723,
#  'semiconductor': 0.7161489537289424,
#  'hopeless': 0.7160186000525695,
#  'baltimore': 0.7159964404769084,
#  'research': 0.7159914493079046,
#  'raises': 0.7159048302408396,
#  'leadoff': 0.7158076373379185,
#  'technical': 0.715410229310059,
#  'superior': 0.7153957754239713,
#  'panda': 0.7153537086806765,
#  'matchfixing': 0.7152650618206287,
#  'sprinter': 0.7152505693352336,
#  'emerson': 0.7151894667766636,
#  'medically': 0.7151612168941469,
#  'daimler': 0.7150594410968156,
#  'revealed': 0.7150574429827228,
#  'cincinnati': 0.7150301416657251,
#  'northampton': 0.7149903256581502,
#  'bust': 0.714962357459747,
#  'generates': 0.7149621816771959,
#  'multilateral': 0.7148208649248025,
#  'damages': 0.7146757964426529,
#  'cyberspace': 0.7146520805942831,
#  'highpowered': 0.7146244604606162,
#  'sponsor': 0.7145903521891247,
#  'cbi': 0.7145503446203401,
#  'scans': 0.7145263469938791,
#  'rowing': 0.7143779369761213,
#  'stark': 0.7140739679358847,
#  'penh': 0.7140583214601637,
#  'heineken': 0.7137143249814584,
#  'huff': 0.71367713941277,
#  'silver': 0.7136483565826491,
#  'athlete': 0.7136392582682224,
#  'ruled': 0.7134041937231543,
#  'humane': 0.7133962250481242,
#  'amend': 0.7132493797723639,
#  'wins': 0.7132236540629915,
#  'secondlargest': 0.7131933307636548,
#  'looted': 0.7131319611041254,
#  'bowden': 0.7130750755429864,
#  'abdulmutallab': 0.7129637213175635,
#  'poker': 0.712938304892629,
#  'adjourned': 0.7128018709281224,
#  'yangon': 0.7127106764759645,
#  'bishop': 0.7124658237670134,
#  'chiang': 0.7123652001836327,
#  'chassis': 0.7123513233994786,
#  'betting': 0.7122277573850829,
#  'indictment': 0.7121526595452982,
#  'reach': 0.7121262844488814,
#  'outing': 0.7121225733147434,
#  'seconddegree': 0.7121038244719324,
#  'comprised': 0.7119657094353379,
#  'tournament': 0.7118450304431618,
#  'ne': 0.71181708322381,
#  'suitable': 0.7117948738912103,
#  'taxpayer': 0.7117844317630564,
#  'londoners': 0.7115973238155101,
#  'beck': 0.7115678260281811,
#  'imaging': 0.7115135667660678,
#  'olympians': 0.7115089107778121,
#  'junta': 0.7114868856604895,
#  'xinjiang': 0.711459420945898,
#  'boa': 0.7114206593252151,
#  'rigorous': 0.7113373590352735,
#  'highprofile': 0.7113177770349229,
#  'flagrant': 0.711168600208554,
#  'registration': 0.7111167641388445,
#  'flooding': 0.7109904144273561,
#  'annals': 0.7109626595525872,
#  'corp': 0.7109015059084968,
#  'file': 0.7108636375063541,
#  'vaccinations': 0.710784096445446,
#  'raleigh': 0.7107204801788386,
#  'den': 0.7106947957580287,
#  'cuckoo': 0.7106835012741689,
#  'secondranked': 0.7105872554049559,
#  'identification': 0.7104710512089455,
#  'assetbacked': 0.7104104643546922,
#  'versions': 0.7103474379179531,
#  'dutch': 0.7103243117469593,
#  'cho': 0.7102570479096966,
#  'odd': 0.7102565452801229,
#  'error': 0.710250151386735,
#  'ipswich': 0.7101687450813443,
#  'reservoir': 0.7100467402325431,
#  'bobby': 0.710040590506768,
#  'shimbun': 0.7100342449245066,
#  'tara': 0.7099921062837466,
#  'nichols': 0.7098120843374509,
#  'intention': 0.7097526961186054,
#  'mcdonnell': 0.7095865619866624,
#  'fratton': 0.709503977807636,
#  'ufj': 0.7094837286844524,
#  'anymore': 0.7094432199614864,
#  'allrounder': 0.709416812170953,
#  'breach': 0.709347590151566,
#  'freestyle': 0.7093443465549119,
#  'liu': 0.7089810374213508,
#  'cement': 0.7089712232984187,
#  'highland': 0.7089416157310785,
#  'nhl': 0.7089264719909203,
#  'giant': 0.7088529720093459,
#  'collects': 0.7088022316392887,
#  'precarious': 0.7087555904268544,
#  'competition': 0.708747349958052,
#  'dignity': 0.708688798762383,
#  'extramarital': 0.7086867077546032,
#  'wimbledon': 0.7086554778343163,
#  'extradite': 0.7086304810673384,
#  'ventura': 0.7085381408369169,
#  'globally': 0.708430073455713,
#  'topical': 0.7083880288631231,
#  'broadest': 0.7083782057295911,
#  'pageant': 0.7083247861973482,
#  'faces': 0.7081634563956687,
#  'botha': 0.7081480190427166,
#  'geothermal': 0.7080459171764637,
#  'prostitution': 0.7079967077696976,
#  'athens': 0.7079612314262139,
#  'sharon': 0.7079164052112424,
#  'switzerland': 0.7078420020570066,
#  'uniform': 0.7077839380512496,
#  'award': 0.7077617313812025,
#  'silva': 0.7077599613665582,
#  'z': 0.7077460650034215,
#  'atmospheric': 0.7073829090160328,
#  'sponsored': 0.7072466809765381,
#  'celebrates': 0.7071301218487958,
#  'landis': 0.7070972939333722,
#  'rebuffed': 0.7070629745655912,
#  'woodland': 0.707061776940252,
#  'prosecutor': 0.7068761729041568,
#  'breached': 0.7068726133560141,
#  'countrywide': 0.7068556745158259,
#  'coo': 0.7067068461985622,
#  'trusted': 0.7066357575870492,
#  'amended': 0.7064954122270457,
#  'tablets': 0.7064349865382611,
#  'fha': 0.70640591889118,
#  'antonio': 0.706336488786376,
#  'fx': 0.7063219181185333,
#  'jo': 0.7062237601285326,
#  'monroe': 0.7061374916538917,
#  'marathon': 0.7061284169889406,
#  'lively': 0.7061174311264116,
#  'csi': 0.7061142682511676,
#  'gaz': 0.7060629184816029,
#  'sebastien': 0.7060236478535533,
#  'enron': 0.706011782494674,
#  'website': 0.7056805883877718,
#  'records': 0.7056747367905338,
#  'forest': 0.7056666142936326,
#  'hillsborough': 0.7055540626290261,
#  'banter': 0.7054781213403423,
#  'bordeaux': 0.7054603678318633,
#  'prosecuting': 0.7054599471820446,
#  'whitney': 0.7054341897091609,
#  'abduction': 0.7053918117963872,
#  'johannesburg': 0.7053789161218273,
#  'stepfather': 0.7052459244788546,
#  'aug': 0.7052221607012042,
#  'main': 0.705176736428742,
#  'structured': 0.7051550383057008,
#  'destruction': 0.7051091407332385,
#  'taxation': 0.7050814654385885,
#  'engineering': 0.7050539541110759,
#  'hart': 0.7050166168942391,
#  'collapse': 0.7050088352478247,
#  'contracts': 0.7050041016948219,
#  'skater': 0.7049834378804345,
#  'suites': 0.7049758247412172,
#  'precedent': 0.7049462431302098,
#  'chapel': 0.7049412781835799,
#  'fugitives': 0.7048973277408401,
#  'alone': 0.7048644434310323,
#  'sheriff': 0.7047617197238794,
#  'buying': 0.7047527749371407,
#  'nfl': 0.7047493704032837,
#  'fla': 0.7047366465590034,
#  'couldn': 0.7047310442102352,
#  'munster': 0.7047137083958457,
#  'edited': 0.7046969650008968,
#  'successful': 0.7046232566506596,
#  'flores': 0.7045059785651897,
#  'broadway': 0.7043939621942819,
#  'retained': 0.7043392652157663,
#  'ospreys': 0.7043238129109054,
#  'lowcarbon': 0.7042565668179702,
#  'recover': 0.7042503165700891,
#  'gays': 0.7042258715409582,
#  'cit': 0.7041722769864872,
#  'sterling': 0.704127175238211,
#  'dodd': 0.704096144656005,
#  'activities': 0.7040939303921494,
#  'contended': 0.7039989817740924,
#  'telegraph': 0.7039894491406401,
#  'alumni': 0.7039721428971019,
#  'forensic': 0.7038491503547395,
#  'cristiano': 0.7037974260695031,
#  'borg': 0.7037885992826296,
#  'quarterbacks': 0.7037584625291744,
#  'circumstances': 0.7037326597031675,
#  'deposits': 0.7037288199609997,
#  'laptops': 0.7037205262158989,
#  'recapture': 0.7035917696863756,
#  'dominance': 0.703525071022779,
#  'armstrong': 0.7035155537744403,
#  'oneday': 0.703471709854974,
#  'transforming': 0.7033291416380189,
#  'transformation': 0.7033250584716972,
#  'disk': 0.7032854792010363,
#  'scam': 0.7032086393396958,
#  'woody': 0.703156329918933,
#  'aung': 0.703134535437656,
#  'prizewinning': 0.7031225455242686,
#  'motor': 0.7030768383743149,
#  'ion': 0.7030533330118773,
#  'determine': 0.7030359038808072,
#  'underpin': 0.7030229067353928,
#  'technically': 0.7030053937054358,
#  'basildon': 0.7030023628338856,
#  'chambers': 0.7027983063434732,
#  'allardyce': 0.7026972542244055,
#  'proceedings': 0.7026888381353532,
#  'worst': 0.7026638788110999,
#  'africa': 0.7025927849174036,
#  'aliens': 0.7025643354385669,
#  'predicts': 0.7024932795148915,
#  'rep': 0.7024335091031619,
#  'zach': 0.7024240510448417,
#  'spartans': 0.7023940504061098,
#  'liquor': 0.7023021958835096,
#  'epidemiology': 0.7022955987063298,
#  'snowboarding': 0.7021293832479136,
#  'creators': 0.702109924459946,
#  'inception': 0.7020567157873999,
#  'regulates': 0.7020188888404219,
#  'ca': 0.7019606134699626,
#  'victoria': 0.7019484595357466,
#  'hostage': 0.7019251080048818,
#  'soccer': 0.7018641163892604,
#  'compact': 0.701842177495323,
#  'procedural': 0.7018111090901931,
#  'reformed': 0.7017850800401407,
#  'trove': 0.7017630106247095,
#  'playmaker': 0.7016960928813003,
#  'bank': 0.7016897998080023,
#  'cornell': 0.7016629827291976,
#  'roasted': 0.7016273012791805,
#  'gbp': 0.7016217726389777,
#  'carlisle': 0.7015759139742528,
#  'canada': 0.7015060645827856,
#  'affordable': 0.7014191107293806,
#  'nbc': 0.7013674989894166,
#  'leinart': 0.7013448976127103,
#  'receipts': 0.7013342971945405,
#  'charities': 0.7013087938945589,
#  'trojans': 0.7012910872111393,
#  'segments': 0.7012519713799057,
#  'pistorius': 0.701234206978105,
#  'postseason': 0.7012153350120768,
#  'urgency': 0.7011558589851925,
#  'prosperous': 0.7011486018254749,
#  'cooling': 0.701119160917719,
#  'built': 0.7009829548926302,
#  'jacksonville': 0.700943697790568,
#  'pontiac': 0.700931054494377,
#  'turner': 0.7008983641632788,
#  'norwich': 0.700800074851737,
#  'nm': 0.700778767010928,
#  'maryland': 0.7006965454335002,
#  'reilly': 0.7006407059181766,
#  'deer': 0.7006135285205071,
#  'dover': 0.7005684275800153,
#  'commissioners': 0.7005021704309975,
#  'conglomerate': 0.7004832190920579,
#  'marvel': 0.700470788979654,
#  'anglican': 0.7004468624304987,
#  'walter': 0.7004342919100243,
#  'immigrant': 0.7003959903070934,
#  'woodstock': 0.7003715988229958,
#  'institution': 0.700353083372546,
#  'phenomenon': 0.7003167613302231,
#  'penguins': 0.7002360179714363,
#  'stanford': 0.700214783461415,
#  'parts': 0.700151331785313,
#  'expedition': 0.7000898072477355,
#  'principles': 0.7000500307554,
#  'os': 0.70003683162942,
#  'trainer': 0.6999915561317415,
#  'herein': 0.6999394660761649,
#  'governmentsponsored': 0.6998847289411173,
#  'bolt': 0.6998272278524376,
#  'basketball': 0.699811859191626,
#  'football': 0.6998108661875859,
#  'cc': 0.6997927815758928,
#  'siemens': 0.699747511981812,
#  'vaccine': 0.6997396193279105,
#  'record': 0.6996774344368073,
#  'giveaway': 0.6996746181804694,
#  'nor': 0.699539013934398,
#  'betrayed': 0.699503383936467,
#  'fouls': 0.6994949998667495,
#  'cheapest': 0.6994798633925263,
#  'latvia': 0.699454063554197,
#  'bebo': 0.6993923941101452,
#  'wines': 0.6993755080809763,
#  'bpa': 0.6993576332143543,
#  'joining': 0.6993489124929188,
#  'cultivation': 0.6993397996766045,
#  'fulfilling': 0.6992857743380791,
#  'verdict': 0.6992805095430359,
#  'participant': 0.6992619186814526,
#  'diversity': 0.6992139017035844,
#  'catholic': 0.6992094692145698,
#  'registrar': 0.69919883637569,
#  'manufacturer': 0.6991892202020625,
#  'withhold': 0.6991681117329984,
#  'brewers': 0.6991423518530709,
#  'politicians': 0.6990497744991366,
#  'cooper': 0.6990281320306934,
#  'sinatra': 0.6990227876703891,
#  'philips': 0.6989900475753735,
#  'cavaliers': 0.6989446817749603,
#  'cousin': 0.6989313121422581,
#  'separate': 0.6989080233777808,
#  'ditch': 0.6988602606402927,
#  'expect': 0.6988367350677462,
#  'bigger': 0.6987949380309723,
#  'miamidade': 0.6986850310516995,
#  'imagery': 0.6986066270272407,
#  'obtain': 0.6985300499438678,
#  'adp': 0.6984932185769978,
#  'optimistic': 0.6984116003213197,
#  'scotland': 0.698398081919352,
#  'promises': 0.6983179746098447,
#  'expects': 0.6982817025934627,
#  'teresa': 0.6982360730365788,
#  'maybe': 0.6982255474630196,
#  'triple': 0.6982215284879225,
#  'june': 0.6981381245409888,
#  'anticipated': 0.6981351740216954,
#  'survey': 0.6981249933103035,
#  'michigan': 0.6980917581842155,
#  'forests': 0.698050628512734,
#  'vertical': 0.6980354169000998,
#  'foyer': 0.6978841665514118,
#  'minerals': 0.6978684659005365,
#  'woods': 0.6978291310826055,
#  'defrauding': 0.6977884166700216,
#  'fàbregas': 0.6976870734855192,
#  'rewarding': 0.6976622201968323,
#  'motors': 0.6976611282474983,
#  'feb': 0.6976588463924568,
#  'nintendo': 0.6976524349223191,
#  'accustomed': 0.6976462298540366,
#  'world': 0.6976136749493049,
#  'ncaa': 0.6975492272372364,
#  'preparation': 0.6975390689242913,
#  'takeover': 0.697535488344339,
#  'crowned': 0.697494640579037,
#  'vinyl': 0.6974381551929046,
#  'ongoing': 0.6974132183131743,
#  'malibu': 0.697385335535399,
#  'substitutes': 0.6973818674322263,
#  'carp': 0.6973428788627292,
#  'antoni': 0.6972767363681558,
#  'assert': 0.6972721856397837,
#  'venture': 0.6972152174774644,
#  'millennium': 0.6971967262147469,
#  'nelson': 0.6971903966525299,
#  'warrior': 0.6971001612559455,
#  'terry': 0.6970957473678698,
#  'reasonably': 0.6970906827936254,
#  'lancashire': 0.6970613240631968,
#  'journal': 0.6970327444011495,
#  'detail': 0.6970276303226275,
#  'evoke': 0.6970218433897333,
#  'ukbased': 0.6970141868558593,
#  'promoted': 0.6969947747633063,
#  'conquered': 0.6969637453400823,
#  'bugs': 0.6969403870014962,
#  'coventry': 0.6969346235083167,
#  'customized': 0.6968594770916936,
#  'sunlight': 0.6968500435338979,
#  'principle': 0.6968390383299627,
#  'levy': 0.696778586315596,
#  'occurred': 0.6967737033099725,
#  'louis': 0.6967335521821179,
#  'sachs': 0.6967316615484657,
#  'excellence': 0.6966438115755716,
#  'stade': 0.6966398466880271,
#  'japanese': 0.6966364534910645,
#  'relate': 0.6966289857761022,
#  'kansas': 0.6966124077726531,
#  'readying': 0.6965762181905002,
#  'until': 0.6965641562370128,
#  'bottles': 0.6964935451702167,
#  'scott': 0.6964804935687734,
#  'sichuan': 0.6964440458758105,
#  'do': 0.6964056763921092,
#  'bundesliga': 0.6964001110938367,
#  'unique': 0.696354026158946,
#  'practices': 0.6963399443419377,
#  'rehearsals': 0.6962529792987697,
#  'ftc': 0.6962335848220615,
#  'headquarters': 0.6962253858549542,
#  'wiped': 0.6962242892667733,
#  'citigroup': 0.6962022327989208,
#  'bending': 0.6961633064342209,
#  'hamilton': 0.6961540114488416,
#  'ticked': 0.6961232044944283,
#  'multimedia': 0.6961109806262131,
#  'historians': 0.6960785618069769,
#  'achieved': 0.6959755540561361,
#  'offers': 0.6959182737170837,
#  'underneath': 0.6958632774694742,
#  'precision': 0.6958453693499588,
#  'commando': 0.6958327463613398,
#  'antidoping': 0.6958263828905858,
#  'required': 0.6958251482347264,
#  'eliot': 0.695812554819168,
#  'preschool': 0.6958065963842743,
#  'suu': 0.6957872118029944,
#  'ha': 0.6957835066728297,
#  'problem': 0.6957638947558598,
#  'label': 0.6956934239551855,
#  'introductions': 0.6956848610002286,
#  'provinces': 0.6956589445857743,
#  'stresses': 0.6956159437990501,
#  'sec': 0.6956009121160366,
#  'penalize': 0.6955907832364978,
#  'inhalation': 0.69558164743778,
#  'sacramento': 0.6955765313297133,
#  'lengths': 0.6955585387328118,
#  'downloads': 0.6955513396852583,
#  'leonardo': 0.69551053963653,
#  'pistachio': 0.6954759744146071,
#  'biggest': 0.6954680449584151,
#  'exxonmobil': 0.6954560294201202,
#  'advisors': 0.6954364213064209,
#  'yn': 0.6954275588092184,
#  'burma': 0.6954257227174196,
#  'merrill': 0.6953670811339616,
#  'endanger': 0.6953412233920564,
#  'lake': 0.6953370072057253,
#  'goaltender': 0.6953152487639723,
#  'execution': 0.6953015396858317,
#  'stems': 0.6952521924479295,
#  'shelley': 0.6952521083709273,
#  'dispense': 0.69524540474896,
#  'dudley': 0.6952138083855839,
#  'separating': 0.6951382776442765,
#  'yemeni': 0.695138024599504,
#  'clout': 0.6951242301627094,
#  'negative': 0.6951195671272186,
#  'examiner': 0.695089431754574,
#  'presidents': 0.6950305711309592,
#  'details': 0.694993311740576,
#  'cocacola': 0.694970749915876,
#  'mike': 0.6949644527773112,
#  'blanket': 0.6949513520212438,
#  'hardliners': 0.6949487470641013,
#  'spirit': 0.6949435095323857,
#  'hd': 0.6949429207161567,
#  'collector': 0.6949117513414816,
#  'nhs': 0.6949076828615262,
#  'pictured': 0.6948887268819908,
#  'tomorrow': 0.6948846143196361,
#  'restoration': 0.6948373781573892,
#  'ives': 0.6948206325605033,
#  'decorative': 0.6947798041312891,
#  'paternity': 0.694644822835791,
#  'medals': 0.6946439590418932,
#  'unless': 0.6946434469744263,
#  'lampard': 0.6945559038427512,
#  'jaguars': 0.6945418702616067,
#  'uighur': 0.6944614373831356,
#  'raptors': 0.6944288173220707,
#  'fibrosis': 0.6943765250650604,
#  'priest': 0.6943686111010011,
#  'sam': 0.6943636125881925,
#  'fast': 0.6942993294625126,
#  'lifting': 0.6942479096787465,
#  'conversion': 0.6942385129566631,
#  'hideouts': 0.6942214891243348,
#  'mapping': 0.694170133405656,
#  'platforms': 0.6941347526852473,
#  'guinness': 0.694087120007779,
#  'respondents': 0.6940858895799933,
#  'illegally': 0.6940737504956639,
#  'competence': 0.6940617028666866,
#  'leicester': 0.6940588344775147,
#  'hills': 0.6940376845842275,
#  'homosexuality': 0.6940071749847032,
#  'indian': 0.6939745311693793,
#  'vodafone': 0.693948365755707,
#  'rico': 0.6939409997831163,
#  'grant': 0.6939135057191423,
#  'prius': 0.6938542367706723,
#  'condom': 0.693848708320052,
#  'repaying': 0.6938179266426004,
#  'qc': 0.6937866732296715,
#  'arrivals': 0.6937574276179561,
#  'corporation': 0.693753832329881,
#  'auditors': 0.6937406940096743,
#  'titan': 0.693738074132759,
#  'assemble': 0.6937359693761923,
#  'injury': 0.6937316230985551,
#  'disappearing': 0.6937285378413915,
#  'filed': 0.6937146730850847,
#  'entire': 0.693679834696757,
#  'norris': 0.6936508387114503,
#  'canseco': 0.6936180320927328,
#  'chengdu': 0.6936157818155275,
#  'magna': 0.6935971233873761,
#  'whistle': 0.6935733099261431,
#  'partnerships': 0.6935682421742495,
#  'richards': 0.6934964504068117,
#  'knew': 0.6934432878928953,
#  'amis': 0.6934379807519249,
#  'dismiss': 0.6934324695718961,
#  'club': 0.6933923971164642,
#  'fashionable': 0.6933569323906791,
#  'placement': 0.6933516467949037,
#  'isolation': 0.6933170658456078,
#  'availability': 0.6933005796593872,
#  'discourage': 0.6932623246644448,
#  'offshoot': 0.6932394079198198,
#  'geoffrey': 0.6932301372525299,
#  'chances': 0.6931725901365482,
#  'sceptical': 0.6931595691001703,
#  'wilmington': 0.6931546473144139,
#  'ibm': 0.6931392561635759,
#  'compete': 0.6931343933296339,
#  'dinosaur': 0.6931214119110826,
#  'sunk': 0.6931085732469594,
#  'dallas': 0.6930648584460412,
#  'emerge': 0.6930186060383245,
#  'aspect': 0.6929756784290264,
#  'prevailed': 0.6929317639424434,
#  'torres': 0.692927394977417,
#  'diversified': 0.6929112891356797,
#  'jury': 0.6929011405949638,
#  'prize': 0.6928888836492102,
#  'netflix': 0.6928490958370055,
#  'induced': 0.6928417190924787,
#  'allergy': 0.6928369257407908,
#  'pumped': 0.6928272319315633,
#  'rutherford': 0.6927734938801374,
#  'panel': 0.6927314696669209,
#  'wonders': 0.6926383422154115,
#  'fires': 0.6926242257220299,
#  'lone': 0.6925788472254708,
#  'subpoenaed': 0.6925600719783908,
#  'publicist': 0.6925490600150959,
#  'deposited': 0.6925412722692104,
#  'texans': 0.6925243248942051,
#  'elena': 0.6925186131582712,
#  'gcses': 0.69251653106653,
#  'misconduct': 0.6924816277377663,
#  'withholding': 0.6924623390423255,
#  'coliseum': 0.6924577773278253,
#  'financiers': 0.6924547334998046,
#  'appeals': 0.6924525736443792,
#  'resonance': 0.6924446105374431,
#  'dealer': 0.6924428548198898,
#  'discusses': 0.6924139235301012,
#  'liechtenstein': 0.6923845326424055,
#  'lawyers': 0.6923793071017484,
#  'heck': 0.6923428138549379,
#  'genentech': 0.6923139278418472,
#  'allowing': 0.692289332382228,
#  'covered': 0.6922854467385019,
#  'pepper': 0.6922755518560375,
#  'lhasa': 0.6922561750275569,
#  'landslide': 0.6922513489427308,
#  'gray': 0.6922368732866504,
#  'covering': 0.6922301619713854,
#  'irony': 0.6922089610063769,
#  'hanson': 0.6922028986558286,
#  'agnieszka': 0.6921231449858269,
#  'keefe': 0.6920930676170376,
#  'motherwell': 0.6920713901063358,
#  'michael': 0.692039071505399,
#  'tempo': 0.6920057927413255,
#  'pharmaceutical': 0.6919875530517705,
#  'credit': 0.69198299812546,
#  'diminish': 0.6919780982176642,
#  'gentleman': 0.69197443797136,
#  'handles': 0.691928655737861,
#  'animal': 0.6919137934838884,
#  'amazing': 0.6918899915449979,
#  'generated': 0.691869653537197,
#  'monsters': 0.6918575719356166,
#  'rees': 0.6918433839447433,
#  'accredited': 0.6918209389766233,
#  'publishing': 0.6917969683773301,
#  'norwegian': 0.6917916975288478,
#  'vivendi': 0.6917907467209765,
#  'contracted': 0.6917830297546712,
#  'achieve': 0.691765444484584,
#  'ailing': 0.6917178058497352,
#  'presenter': 0.6917036095259541,
#  'bengals': 0.6916604246570777,
#  'appellate': 0.6916020371412233,
#  'losers': 0.6915970732674706,
#  'franz': 0.6915742874272349,
#  'branches': 0.6915335737807664,
#  'stem': 0.6915335331137161,
#  'eduardo': 0.6915175312945807,
#  'alongside': 0.6915094062892583,
#  'decidedly': 0.6914982946985461,
#  'es': 0.6914925712213207,
#  'honest': 0.6914504446365455,
#  'integrating': 0.6914078583549468,
#  'ruining': 0.691390854290282,
#  'tightly': 0.6913734111988528,
#  'stairs': 0.6913532224347206,
#  'allocated': 0.6913442901803692,
#  'assembling': 0.6913360517642742,
#  'represent': 0.6912660949146364,
#  'aberdeen': 0.6912431506878505,
#  'arrogance': 0.6911846558149075,
#  'nonpartisan': 0.6911843761874084,
#  'posting': 0.691182706339903,
#  'directorgeneral': 0.6911512661246555,
#  'ohio': 0.6911434630320236,
#  'caucasian': 0.691114037747967,
#  'infection': 0.691007777384365,
#  'diverse': 0.690955312807461,
#  'aluminium': 0.6909329917634599,
#  'prom': 0.6909089318888157,
#  'puerto': 0.6908644996942855,
#  'gamble': 0.6908191029738994,
#  'believes': 0.6907945483088443,
#  'scheme': 0.6907640164272588,
#  'charlie': 0.6907079035881398,
#  'scenario': 0.6906911588916246,
#  'journalists': 0.6906088685245311,
#  'remnants': 0.6905880700081422,
#  'shooter': 0.6905193355001733,
#  'tb': 0.6904550285369114,
#  'avoid': 0.690444498365072,
#  'interpretations': 0.6904253484920957,
#  'homicide': 0.6903990129735217,
#  'outcomes': 0.6903929886706517,
#  'captains': 0.6903795506319996,
#  'criticize': 0.6903524566008978,
#  'invitations': 0.6903373584958478,
#  'pre': 0.6903230376406733,
#  'frightening': 0.6902890158478249,
#  'ge': 0.6902805191666306,
#  'mines': 0.6902653485089529,
#  'pancreas': 0.6902405434629896,
#  'slumping': 0.6902320260068168,
#  'enthusiast': 0.6902317662426132,
#  'reclaim': 0.6902186873224453,
#  'deutsche': 0.6901603810189673,
#  'occupation': 0.690105278815023,
#  'haas': 0.6900866834151598,
#  'necessity': 0.6900802606712606,
#  'true': 0.6900463475044535,
#  'hilltop': 0.6900325223414613,
#  'singletary': 0.6900273519521474,
#  'addition': 0.6900076558232877,
#  'lukas': 0.6899988824009804,
#  'detainee': 0.689959366880656,
#  'manufacturers': 0.6899080530833025,
#  'stringent': 0.68987620099279,
#  'kuala': 0.6898539666859309,
#  'encompasses': 0.6898021066632989,
#  'publishes': 0.6897427564968868,
#  'expo': 0.6896988518274603,
#  'marijuana': 0.689673513652104,
#  'weakness': 0.6896686857650548,
#  'pettitte': 0.689646899443506,
#  'nestle': 0.6895675650906935,
#  'challenges': 0.6895432519758462,
#  'knights': 0.6894903561322805,
#  'undertaking': 0.6894766488672838,
#  'professor': 0.6894691691530568,
#  'robert': 0.6894551149020339,
#  'coveted': 0.68942793530831,
#  'certainly': 0.6894262675448788,
#  'marine': 0.6894193108959851,
#  'e': 0.6893745020079113,
#  'froze': 0.6893742175131052,
#  'sped': 0.6893326624540197,
#  'figures': 0.6893289122707452,
#  'itself': 0.6892960751971351,
#  'spinoff': 0.6892823642486479,
#  'secrets': 0.6892393110260009,
#  'outstanding': 0.6892239434437218,
#  'princeton': 0.6892130526009611,
#  'acquittal': 0.6891773428883179,
#  'cos': 0.6891629005527199,
#  'unclear': 0.6890672703608843,
#  'jane': 0.689063041874239,
#  'goahead': 0.689056743205068,
#  'teamed': 0.6890090531762317,
#  'scientists': 0.6889964242464985,
#  'postpone': 0.688965176154352,
#  'golan': 0.6889629087519263,
#  'painted': 0.688961569240397,
#  'jp': 0.6889367411907306,
#  'traditionally': 0.6889309683926639,
#  'recipient': 0.6889061273790147,
#  'greeks': 0.6888903905548003,
#  'instances': 0.6888706014225549,
#  'cerberus': 0.6888485060234619,
#  'improvement': 0.6888337038871581,
#  'niger': 0.6888300388473145,
#  'solo': 0.6888266538104746,
#  'forgo': 0.6888237100393766,
#  'abu': 0.6887799183584775,
#  'july': 0.688779624382752,
#  'renault': 0.6887357100246635,
#  'elite': 0.6887280682452734,
#  'chase': 0.6887232306428338,
#  'secondbiggest': 0.6887065226086349,
#  'adriano': 0.688687010379599,
#  'mbia': 0.6886790390139123,
#  'preference': 0.688658006367182,
#  'cooler': 0.6886022270614945,
#  'speeding': 0.6885911186915596,
#  'enhances': 0.6885687357241449,
#  'tenants': 0.6885605889515075,
#  'semifinals': 0.6885579331563012,
#  'district': 0.6885280657028399,
#  'payers': 0.688519147726883,
#  'unbelievable': 0.6885173874982832,
#  'ireland': 0.688510619172346,
#  'favorite': 0.6885011642283,
#  'midth': 0.6884948709043577,
#  'real': 0.6884634843737225,
#  'dnc': 0.6884150376497392,
#  'batteries': 0.6884001451743984,
#  'objectivity': 0.6883792205107265,
#  'patti': 0.6883588715838193,
#  'offshore': 0.6883522122178197,
#  'taxpayers': 0.6883452466637452,
#  'archbishop': 0.688326484849908,
#  'susceptible': 0.6883065293922297,
#  'vale': 0.688297225433129,
#  'glow': 0.6882851740524225,
#  'qualify': 0.6882724655406415,
#  'llc': 0.6882661637160974,
#  'valle': 0.6882606128264923,
#  'wonderful': 0.6882535168746182,
#  'cfo': 0.6882529508955928,
#  'landscape': 0.6882465343663379,
#  'fe': 0.6882424105108154,
#  'mcgeechan': 0.6882348016111782,
#  'consultants': 0.6882297520979505,
#  'reinforces': 0.6882177533797186,
#  'viability': 0.6881891505722912,
#  'premise': 0.6881853009544444,
#  'executives': 0.6881642741747237,
#  'swimmer': 0.6881228484868254,
#  'hear': 0.6881129217875557,
#  'animosity': 0.6880737030921508,
#  'obstruction': 0.6880696329720132,
#  'sean': 0.6880612104587689,
#  'patents': 0.6880464133509756,
#  'galaxy': 0.6880451610626779,
#  'tribune': 0.6880376771607244,
#  'heard': 0.6880144591805543,
#  'completely': 0.6880082116994002,
#  'churches': 0.6879188186067419,
#  'rundown': 0.6878988816493573,
#  'oct': 0.6878724335932538,
#  'briefed': 0.6878071314321228,
#  'mighty': 0.6877676957032256,
#  'design': 0.687765509018613,
#  'documents': 0.6877611728191872,
#  'evolve': 0.6877559455114974,
#  'succeeds': 0.6877504084866913,
#  'greeting': 0.6877330244628914,
#  'learned': 0.6877256837151466,
#  'planet': 0.68772203393094,
#  'terminal': 0.6877062823390936,
#  'countless': 0.6876999174883593,
#  'disappointing': 0.6876855188641742,
#  'shutout': 0.6876442545426192,
#  'mets': 0.6876293482606911,
#  'convert': 0.6876067299326543,
#  'mogadishu': 0.6875795569846255,
#  'austrian': 0.6875657599951417,
#  'soldier': 0.6875551681464578,
#  'jerry': 0.6874723507055336,
#  'shadows': 0.6873993567989605,
#  'bair': 0.6873976996137124,
#  'syndicated': 0.6873945223276834,
#  'brazil': 0.6873696134686147,
#  'mac': 0.6873493255055281,
#  'graceful': 0.6873320912193427,
#  'fayed': 0.6872574635673937,
#  'wallpaper': 0.6872453757775928,
#  'whiting': 0.6872385602605391,
#  'marketing': 0.6871903496497679,
#  'sabmiller': 0.6871542897949185,
#  'explored': 0.6871425779575628,
#  'sox': 0.6871335892809227,
#  'juarez': 0.6871322092118652,
#  'stone': 0.6871149454219881,
#  'broadening': 0.6870424258817467,
#  'survive': 0.6870232041271213,
#  'kew': 0.6870115009992537,
#  'stadiums': 0.6869654740447584,
#  'butler': 0.6869488291963881,
#  'heartland': 0.6869425187439853,
#  'hgh': 0.6869017953441933,
#  'multinational': 0.6868876524307382,
#  'transparent': 0.6868777065056227,
#  'goran': 0.6868700523033532,
#  'brand': 0.6868659116636304,
#  'murderer': 0.6868374194478989,
#  'wakeup': 0.6868319220884793,
#  'anfield': 0.6868199644811469,
#  'test': 0.6867863143964832,
#  'sierra': 0.6867607370056716,
#  'spearheaded': 0.6867571625784795,
#  'testing': 0.6866777031436183,
#  'yettaw': 0.6865932131585173,
#  'lanka': 0.6865786309794039,
#  'northwestern': 0.6865531208326607,
#  'fifth': 0.6865468439585279,
#  'fire': 0.6865301380978217,
#  'bombay': 0.6865091199804183,
#  'thinks': 0.686489323423098,
#  'homeless': 0.6864833628699377,
#  'emancipation': 0.686480684774061,
#  'draper': 0.6864774937384365,
#  'todd': 0.6864366285303288,
#  ...}
